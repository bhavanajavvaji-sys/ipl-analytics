# %% [markdown]
# # IPL Analytics 2008 - 2025
# ## Notebook 1 - Data Loading & CLeaning
# **Goal:** Load the dataset, understand its structure, fix data qualtiy issues and prepare it for analysis.

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("seaborn-v0_8")

print("Libraries loaded successfully")
print(f"Pandas version: {pd.__version__}")
print(f"Numpy version: {np.__version__}")
# Out:
# Libraries loaded successfully
# Pandas version: 2.3.3
# Numpy version: 2.4.0

# %%
df = pd.read_csv('../data/IPL.csv')

print(f"data loaded successfully")
print(f"Rows : {df.shape[0]:,}")
print(f"Columns: {df.shape[1]}")
print(f"Total data points: {df.shape[0]*df.shape[1]:,}")
# Out:
# C:\Users\bhava\AppData\Local\Temp\ipykernel_26704\2779004139.py:1: DtypeWarning: Columns (28,29,30,31,43,46,47,48,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/IPL.csv')
# data loaded successfully
# Rows : 278,205
# Columns: 64
# Total data points: 17,805,120

# %%
print("=== FIRST 3 ROWs ===")
df.head(3)
# Out:
# === FIRST 3 ROWs ===
#    Unnamed: 0  match_id        date match_type             event_name  \
# 0      131970    335982  2008-04-18        T20  Indian Premier League
# 1      131971    335982  2008-04-18        T20  Indian Premier League
# 2      131972    335982  2008-04-18        T20  Indian Premier League
#
#    innings           batting_team                 bowling_team  over  ball  \
# 0        1  Kolkata Knight Riders  Royal Challengers Bangalore     0     1
# 1        1  Kolkata Knight Riders  Royal Challengers Bangalore     0     2
# 2        1  Kolkata Knight Riders  Royal Challengers Bangalore     0     3
#
#    ...  team_runs team_balls  team_wicket  new_batter  batter_runs  \
# 0  ...          1          1            0         NaN            0
# 1  ...          1          2            0         NaN            0
# 2  ...          2          2            0         NaN            0
#
#   batter_balls  bowler_wicket               batting_partners  next_batter  \
# 0            1              0  ('BB McCullum', 'SC Ganguly')          NaN
# 1            1              0  ('BB McCullum', 'SC Ganguly')          NaN
# 2            1              0  ('BB McCullum', 'SC Ganguly')          NaN
#
#    striker_out
# 0        False
# 1        False
# 2        False
#
# [3 rows x 64 columns]

# %%
print("=== COLUMN INFORMATION ===")
print(f"{'column':<25} {'Non-Null': <15} {'Dtype'}")
print("-"* 50)
for col in df.columns:
    non_null = df[col].notna().sum()
    dtype = df[col].dtype
    print(f"{col:<25} {non_null:<15} {dtype}")
# Out:
# === COLUMN INFORMATION ===
# column                    Non-Null        Dtype
# --------------------------------------------------
# Unnamed: 0                278205          int64
# match_id                  278205          int64
# date                      278205          object
# match_type                278205          object
# event_name                278205          object
# innings                   278205          int64
# batting_team              278205          object
# bowling_team              278205          object
# over                      278205          int64
# ball                      278205          int64
# ball_no                   278205          float64
# batter                    278205          object
# bat_pos                   278205          int64
# runs_batter               278205          int64
# balls_faced               278205          int64
# bowler                    278205          object
# valid_ball                278205          int64
# runs_extras               278205          int64
# runs_total                278205          int64
# runs_bowler               278205          int64
# runs_not_boundary         278205          bool
# extra_type                15133           object
# non_striker               278205          object
# non_striker_pos           278205          int64
# wicket_kind               13823           object
# player_out                13823           object
# fielders                  10013           object
# runs_target               133903          float64
# review_batter             872             object
# team_reviewed             872             object
# review_decision           872             object
# umpire                    872             object
# umpires_call              278205          bool
# player_of_match           278205          object
# match_won_by              278205          object
# win_outcome               273503          object
# toss_winner               278205          object
# toss_decision             278205          object
# venue                     278205          object
# city                      278205          object
# day                       278205          int64
# month                     278205          int64
# year                      278205          int64
# season                    278205          object
# gender                    278205          object
# team_type                 278205          object
# superover_winner          3896            object
# result_type               4702            object
# method                    3890            object
# balls_per_over            278205          int64
# overs                     278205          int64
# event_match_no            278205          object
# stage                     278205          object
# match_number              278205          object
# team_runs                 278205          int64
# team_balls                278205          int64
# team_wicket               278205          int64
# new_batter                13321           object
# batter_runs               278205          int64
# batter_balls              278205          int64
# bowler_wicket             278205          int64
# batting_partners          278205          object
# next_batter               13321           object
# striker_out               278205          bool
